# %%
import pandas as pd
import seaborn as sns
import numpy as np 


df_age = pd.read_csv('interests-of-users-by-age.csv')
df_age
# Out:
#     index  age  nbusers  percentwantchats  percentwantfriends  \
# 0       0   18        1               0.0                 0.0
# 1       1   19      523              65.8                62.5
# 2       2   20      524              67.6                64.9
# 3       3   21      603              64.0                63.0
# 4       4   22      720              59.9                60.6
# 5       5   23      593              59.7                64.8
# 6       6   24      534              61.0                61.4
# 7       7   25      356              60.1                62.4
# 8       8   26      117              65.0                62.4
# 9       9   27        1             100.0                 0.0
# 10     10   28        1               0.0                 0.0
#
#     percentwantdates  meankissesreceived  meanvisitsreceived  meanfollowers  \
# 0                0.0                   0                 0.0            0.0
# 1               34.2                 179              4279.5            2.6
# 2               37.2                 208              4809.5            1.8
# 3               35.7                 167              4093.0            2.1
# 4               40.3                 134              3302.9            1.7
# 5               39.5                 161              3632.6            3.1
# 6               39.7                 127              3009.6            2.6
# 7               44.4                 115              2902.8            2.6
# 8               47.0                 146              2839.6            3.9
# 9                0.0                 661              8755.0            0.0
# 10               0.0                   0                 0.0            0.0
#
#     meanlanguagesknown  totalwantchants  totalwantfriends  totalwantdates  \
# 0                 1.00                0                 0               0
# 1                 1.15              344               327             179
# 2                 1.12              354               340             195
# 3                 1.12              386               380             215
# 4                 1.07              431               436             290
# 5                 1.09              354               384             234
# 6                 1.12              326               328             212
# 7                 1.10              214               222             158
# 8                 1.07               76                73              55
# 9                 1.00                1                 0               0
# 10                5.00                0                 0               0
#
#     totalkissesreceive  totalvisitsreceived  totalfollowers  \
# 0                    0                    0               0
# 1                93985              2238190            1374
# 2               109490              2520195             934
# 3               101063              2468100            1239
# 4                96505              2378122            1201
# 5                95646              2154138            1811
# 6                68183              1607127            1378
# 7                41200              1033400             923
# 8                17118               332231             455
# 9                  661                 8755               0
# 10                   0                    0               0
#
#     totallanguagesspoken
# 0                      1
# 1                    601
# 2                    586
# 3                    678
# 4                    771
# 5                    648
# 6                    599
# 7                    392
# 8                    125
# 9                      1
# 10                     5

# %%
df1 = pd.read_csv('lovoo_v3_users_api-results.csv')
df1
# Out:
#       index gender genderLooking  age          name  counts_details  \
# 0         0      F             M   25         daeni            1.00
# 1         1      F             M   22   italiana 92            0.85
# 2         2      F             M   21       Lauraaa            0.00
# 3         3      F          none   20    Qqkwmdowlo            0.12
# 4         4      F             M   21  schaessie {3            0.15
# ...     ...    ...           ...  ...           ...             ...
# 3968   3968      F             M   21          B**f            0.85
# 3969   3969      F             M   20         Ma**e            1.00
# 3970   3970      F             M   20         Ma**e            1.00
# 3971   3971      F             M   23        Eni**n            0.96
# 3972   3972      F             M   23        Eni**n            0.96
#
#       counts_pictures  counts_profileVisits  counts_kisses  counts_fans  ...  \
# 0                   4                  8279            239            0  ...
# 1                   5                   663             13            0  ...
# 2                   4                  1369             88            0  ...
# 3                   3                 22187           1015            2  ...
# 4                  12                 35262           1413            9  ...
# ...               ...                   ...            ...          ...  ...
# 3968                1                   280             15            0  ...
# 3969                8                  1014             43            3  ...
# 3970                8                  1101             46            3  ...
# 3971                8                  8702            142            0  ...
# 3972                9                  8904            143            0  ...
#
#       shareProfileEnabled        lastOnlineDate  lastOnlineTime  birthd crypt  \
# 0                       1  2015-04-25T20:43:26Z    1.429995e+09       0   NaN
# 1                       1  2015-04-26T09:19:35Z    1.430040e+09       0   NaN
# 2                       1  2015-04-06T14:24:07Z    1.428330e+09       0   NaN
# 3                       1  2015-04-07T11:21:01Z    1.428406e+09       0   NaN
# 4                       1  2015-04-06T14:25:20Z    1.428330e+09       0   NaN
# ...                   ...                   ...             ...     ...   ...
# 3968                    1  2015-04-07T00:08:59Z    1.428365e+09       0   1.0
# 3969                    1  2015-04-06T07:54:34Z    1.428307e+09       0   1.0
# 3970                    1  2015-04-06T07:54:34Z    1.428307e+09       0   1.0
# 3971                    0  2015-04-06T15:47:15Z    1.428335e+09       0   1.0
# 3972                    0  2015-04-19T08:38:08Z    1.429433e+09       0   1.0
#
#                                     freetext  \
# 0     Nur tote Fisch schwimmen mit dem Strom
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ...                                      ...
# 3968                                     NaN
# 3969                                     NaN
# 3970                                     NaN
# 3971                                     NaN
# 3972                                     NaN
#
#                                                 whazzup  \
# 0               Nur tote fische schwimmen mit dem strom
# 1                                         Primaveraaa<3
# 2                                                   NaN
# 3              Je pense donc je suis.  Instagram quedev
# 4                                 Instagram: JESSSIESCH
# ...                                                 ...
# 3968                                                NaN
# 3969  Marie ॐ                            🎉Goa.      ...
# 3970  Marie ॐ                            🎉Goa.      ...
# 3971                           ruhig shriebe😉. bissä ni
# 3972                           ruhig shriebe😉. bissä ni
#
#                                               pictureId  \
# 0                              4e3842f79b70e7ea57000064
# 1                              4e3d34bf5d2bce7b160006a3
# 2                              4ec96c090dc82cb25d00000a
# 3                              4eef8b81ebf2c8f64000000c
# 4                              4ef3cc5aa9d0b3d07d000017
# ...                                                 ...
# 3968  CRYqKLbQ1+pd5CVSmGGccV+EggT4oGRmaXWhnn5jhMg9Jz...
# 3969  CRYq7MGpxHpEKfWhmwJygGmRNadHkC9XxPjktwvaiLm6Te...
# 3970  CRYVOrW7zgSV+NPGili4nZeREmQ0rAAXCZunTXp9KRLat1...
# 3971  CRYsH4q+r4fCkC8+leJqDdJQtbUNQGCyqLx36aDsEzC5b9...
# 3972  CRYbrX0C8ToNrsDqLPf+kLsCSuDY0TOhyKSo3Phw98sbl+...
#
#                                 userId  isSystemProfile
# 0             55303fc3160ba0eb728b4575              NaN
# 1             552e7b61c66da10d1e8b4c82              NaN
# 2             54a584ecc56da128638b4674              NaN
# 3             54c92738076ea1b5338b4735              NaN
# 4             54e1a6f6c76da135748b4a3a              NaN
# ...                                ...              ...
# 3968  cb958a9459216acd4dd06f213fe63685              NaN
# 3969  d5a7edbcb59fcb092871bdcde7f142ca              NaN
# 3970  d5a7edbcb59fcb092871bdcde7f142ca              NaN
# 3971  e532a6060fe4e5902c66086d905a9d53              NaN
# 3972  dc186f3855343c9f096c484f6d363aac              NaN
#
# [3973 rows x 43 columns]

# %%
df1 = df1.drop(['name','whazzup','pictureId','userId'], axis=1)

# %%
df1
# Out:
#       index gender genderLooking  age  counts_details  counts_pictures  \
# 0         0      F             M   25            1.00                4
# 1         1      F             M   22            0.85                5
# 2         2      F             M   21            0.00                4
# 3         3      F          none   20            0.12                3
# 4         4      F             M   21            0.15               12
# ...     ...    ...           ...  ...             ...              ...
# 3968   3968      F             M   21            0.85                1
# 3969   3969      F             M   20            1.00                8
# 3970   3970      F             M   20            1.00                8
# 3971   3971      F             M   23            0.96                8
# 3972   3972      F             M   23            0.96                9
#
#       counts_profileVisits  counts_kisses  counts_fans  counts_g  ...  \
# 0                     8279            239            0         3  ...
# 1                      663             13            0         0  ...
# 2                     1369             88            0         2  ...
# 3                    22187           1015            2         3  ...
# 4                    35262           1413            9        12  ...
# ...                    ...            ...          ...       ...  ...
# 3968                   280             15            0         0  ...
# 3969                  1014             43            3         0  ...
# 3970                  1101             46            3         0  ...
# 3971                  8702            142            0         0  ...
# 3972                  8904            143            0         0  ...
#
#       lang_es  lang_pt  verified shareProfileEnabled        lastOnlineDate  \
# 0       False    False         0                   1  2015-04-25T20:43:26Z
# 1       False    False         0                   1  2015-04-26T09:19:35Z
# 2       False    False         0                   1  2015-04-06T14:24:07Z
# 3       False    False         0                   1  2015-04-07T11:21:01Z
# 4       False    False         0                   1  2015-04-06T14:25:20Z
# ...       ...      ...       ...                 ...                   ...
# 3968    False    False         0                   1  2015-04-07T00:08:59Z
# 3969    False    False         0                   1  2015-04-06T07:54:34Z
# 3970    False    False         0                   1  2015-04-06T07:54:34Z
# 3971    False    False         0                   0  2015-04-06T15:47:15Z
# 3972    False    False         0                   0  2015-04-19T08:38:08Z
#
#      lastOnlineTime  birthd  crypt                                freetext  \
# 0      1.429995e+09       0    NaN  Nur tote Fisch schwimmen mit dem Strom
# 1      1.430040e+09       0    NaN                                     NaN
# 2      1.428330e+09       0    NaN                                     NaN
# 3      1.428406e+09       0    NaN                                     NaN
# 4      1.428330e+09       0    NaN                                     NaN
# ...             ...     ...    ...                                     ...
# 3968   1.428365e+09       0    1.0                                     NaN
# 3969   1.428307e+09       0    1.0                                     NaN
# 3970   1.428307e+09       0    1.0                                     NaN
# 3971   1.428335e+09       0    1.0                                     NaN
# 3972   1.429433e+09       0    1.0                                     NaN
#
#       isSystemProfile
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 3968              NaN
# 3969              NaN
# 3970              NaN
# 3971              NaN
# 3972              NaN
#
# [3973 rows x 39 columns]

# %%
df2 = pd.read_csv('lovoo_v3_users_instances.csv')

# %%
df2
# Out:
#       index gender  age         name  counts_pictures  counts_profileVisits  \
# 0         0      F   25        daeni                4                  8279
# 1         1      F   22  italiana 92                5                   663
# 2         2      F   20   Qqkwmdowlo                3                 22187
# 3         3      F   24     Baby dee               18                  7339
# 4         4      F   24         Anna               13                 18672
# ...     ...    ...  ...          ...              ...                   ...
# 2914   2914      F   20        Ma**e                8                  1101
# 2915   2915      F   23       Eni**n                8                  8681
# 2916   2916      F   23       Eni**n                8                  8682
# 2917   2917      F   23       Eni**n                8                  8702
# 2918   2918      F   23       Eni**n                9                  8904
#
#       counts_kisses  flirtInterests_chat  flirtInterests_friends  \
# 0               239                 True                    True
# 1                13                 True                    True
# 2              1015                 True                    True
# 3               180                 True                   False
# 4               492                False                    True
# ...             ...                  ...                     ...
# 2914             46                 True                    True
# 2915            141                 True                    True
# 2916            141                 True                    True
# 2917            142                 True                    True
# 2918            143                 True                    True
#
#       flirtInterests_date  ...  hasBirthday  highlighted    distance locked  \
# 0                    True  ...        False        False  175.000000  False
# 1                    True  ...        False        False  138.000000  False
# 2                   False  ...        False        False   77.300003  False
# 3                    True  ...        False        False  194.000000  False
# 4                   False  ...        False        False  318.000000  False
# ...                   ...  ...          ...          ...         ...    ...
# 2914                 True  ...        False        False    0.000000  False
# 2915                 True  ...        False        False    0.000000   True
# 2916                 True  ...        False        False    0.000000   True
# 2917                 True  ...        False        False    0.000000  False
# 2918                 True  ...        False        False    0.000000  False
#
#       mobile  online                                            whazzup  \
# 0       True   False            Nur tote fische schwimmen mit dem strom
# 1       True   False                                      Primaveraaa<3
# 2      False   False            Je pense donc je suis. Instagram quedev
# 3       True    True                               Wicked Wonderland💕❤️
# 4       True    True                         💚 ✅ Instagram : anna_lem0n
# ...      ...     ...                                                ...
# 2914   False   False  Marie ॐ              🎉Goa.         Facebook:Ma...
# 2915    True    True                           ruhig shriebe😉. bissä ni
# 2916    True   False                           ruhig shriebe😉. bissä ni
# 2917    True    True                           ruhig shriebe😉. bissä ni
# 2918    True   False                           ruhig shriebe😉. bissä ni
#
#                                               pictureId  \
# 0                              4e3842f79b70e7ea57000064
# 1                              4e3d34bf5d2bce7b160006a3
# 2                              4eef8b81ebf2c8f64000000c
# 3                              4ef9434cca61bece6a000002
# 4                              4f10cbc1883fa97a5f000015
# ...                                                 ...
# 2914  CRYVOrW7zgSV+NPGili4nZeREmQ0rAAXCZunTXp9KRLat1...
# 2915  CRYohLWFV8BkxZIvOom42Cwo3ysdViv+oTosUAOQkLKHTM...
# 2916  CRYz85gM+yTETN5FonrExXNHyDuwarWygCPnUrwnan7Uet...
# 2917  CRYsH4q+r4fCkC8+leJqDdJQtbUNQGCyqLx36aDsEzC5b9...
# 2918  CRYbrX0C8ToNrsDqLPf+kLsCSuDY0TOhyKSo3Phw98sbl+...
#
#                                 userId  isSystemProfile
# 0             55303fc3160ba0eb728b4575            False
# 1             552e7b61c66da10d1e8b4c82            False
# 2             54c92738076ea1b5338b4735            False
# 3             54f2b4ce0b6ea1177e8b4d18            False
# 4             54ecbb39170ba08b488b4aa5            False
# ...                                ...              ...
# 2914  d5a7edbcb59fcb092871bdcde7f142ca            False
# 2915  e532a6060fe4e5902c66086d905a9d53            False
# 2916  e532a6060fe4e5902c66086d905a9d53            False
# 2917  e532a6060fe4e5902c66086d905a9d53            False
# 2918  dc186f3855343c9f096c484f6d363aac            False
#
# [2919 rows x 40 columns]
